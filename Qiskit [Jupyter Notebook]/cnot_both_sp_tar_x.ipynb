# %%
from qiskit import *
from qiskit.visualization import plot_bloch_multivector, visualize_transition, plot_histogram

# %%
# Create a quantum circuit with 2 qubits
# The default initial state of qubits will be |0> or [1,0]
qc = QuantumCircuit(2)

# %%
# Apply h gate to the control qubit
qc.h(0)
# apply pauli x gate to the target qubit
qc.x(1)
# Apply h gate to the target qubit
qc.h(1)

# %%
#Applying the CNOT gate
qc.cx(0,1)

# %%
#Draw the circuit
# qc.draw()
qc.draw('mpl')

# %%
#Get the backend for the circuit to display unitary matrix
backend = Aer.get_backend('unitary_simulator')

# %%
#execute the circuit using the backend
out = execute(qc,backend).result().get_unitary()

# %%
#import qiskit_textbook and display the combined unitary matrix
from qiskit_textbook.tools import array_to_latex
array_to_latex(out, pretext = "\\text{UnitaryMatrix} = ")
# Out:
# $\displaystyle
# \text{UnitaryMatrix} = \begin{bmatrix}
# \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2}  \\
# -\tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2} & -\tfrac{1}{2}  \\
# -\tfrac{1}{2} & -\tfrac{1}{2} & \tfrac{1}{2} & \tfrac{1}{2}  \\
# \tfrac{1}{2} & -\tfrac{1}{2} & \tfrac{1}{2} & -\tfrac{1}{2}  \\
# \end{bmatrix}
# $$
# $

# %%
#Get the backend for the circuit (simulator or realtime system)
backend = Aer.get_backend('statevector_simulator')

# %%
#execute the circuit using the backend
out = execute(qc,backend).result().get_statevector()

# %%
#import qiskit_textbook and display the statevector
#from qiskit_textbook.tools import array_to_latex
array_to_latex(out, pretext = "\\text{Statevector} = ")
# Out:
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{2} \\
# -\tfrac{1}{2} \\
# -\tfrac{1}{2} \\
# \tfrac{1}{2}
# \end{bmatrix}
# $

# %%
#execute the circuit and get the plain result
out = execute(qc,backend).result()
#getting the count of the result
counts = out.get_counts()
#plotting the histogram
plot_histogram(counts)

# %%
pip install git+https://github.com/qiskit-community/qiskit-textbook.git#subdirectory=qiskit-textbook-src
# Out:
# Collecting git+https://github.com/qiskit-community/qiskit-textbook.git#subdirectory=qiskit-textbook-src
#   Cloning https://github.com/qiskit-community/qiskit-textbook.git to c:\users\minnu\appdata\local\temp\pip-req-build-03ik9flx
#   Resolved https://github.com/qiskit-community/qiskit-textbook.git to commit 0ae905083ec3872d7ddc6bb4001d5468f476d93f
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: qiskit in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (0.43.0)
# Requirement already satisfied: ipython in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (8.10.0)
# Requirement already satisfied: ipywidgets in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (7.6.5)
# Requirement already satisfied: numpy in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (3.7.0)
# Requirement already satisfied: numexpr in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-textbook==0.1.0) (2.8.4)
# Requirement already satisfied: colorama in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.4.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (3.0.36)
# Requirement already satisfied: traitlets>=5 in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (5.7.1)
# Requirement already satisfied: decorator in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (2.11.2)
# Requirement already satisfied: backcall in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\minnu\anaconda3\lib\site-packages (from ipython->qiskit-textbook==0.1.0) (0.7.5)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipywidgets->qiskit-textbook==0.1.0) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipywidgets->qiskit-textbook==0.1.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipywidgets->qiskit-textbook==0.1.0) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipywidgets->qiskit-textbook==0.1.0) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\minnu\anaconda3\lib\site-packages (from ipywidgets->qiskit-textbook==0.1.0) (6.19.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\minnu\anaconda3\lib\site-packages (from matplotlib->qiskit-textbook==0.1.0) (1.0.5)
# Requirement already satisfied: qiskit-ibmq-provider==0.20.2 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit->qiskit-textbook==0.1.0) (0.20.2)
# Requirement already satisfied: qiskit-aer==0.12.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit->qiskit-textbook==0.1.0) (0.12.0)
# Requirement already satisfied: qiskit-terra==0.24.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit->qiskit-textbook==0.1.0) (0.24.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-aer==0.12.0->qiskit->qiskit-textbook==0.1.0) (1.10.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (1.26.14)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (1.5.2)
# Requirement already satisfied: requests>=2.19 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (2.31.0)
# Requirement already satisfied: requests-ntlm<=1.1.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (1.1.0)
# Requirement already satisfied: websockets>=10.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (11.0.3)
# Requirement already satisfied: sympy>=1.3 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (0.3.6)
# Requirement already satisfied: psutil>=5 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (5.9.0)
# Requirement already satisfied: rustworkx>=0.12.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (0.12.1)
# Requirement already satisfied: ply>=3.10 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (3.11)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\minnu\anaconda3\lib\site-packages (from qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (5.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (23.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in c:\users\minnu\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\minnu\anaconda3\lib\site-packages (from jedi>=0.16->ipython->qiskit-textbook==0.1.0) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\minnu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\minnu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (2.16.2)
# Requirement already satisfied: jupyter-core in c:\users\minnu\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (5.2.0)
# Requirement already satisfied: wcwidth in c:\users\minnu\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython->qiskit-textbook==0.1.0) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\minnu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->qiskit-textbook==0.1.0) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\minnu\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (6.5.2)
# Requirement already satisfied: asttokens in c:\users\minnu\anaconda3\lib\site-packages (from stack-data->ipython->qiskit-textbook==0.1.0) (2.0.5)
# Requirement already satisfied: executing in c:\users\minnu\anaconda3\lib\site-packages (from stack-data->ipython->qiskit-textbook==0.1.0) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\minnu\anaconda3\lib\site-packages (from stack-data->ipython->qiskit-textbook==0.1.0) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\minnu\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\minnu\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (22.1.0)
# Requirement already satisfied: entrypoints in c:\users\minnu\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->qiskit-textbook==0.1.0) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\minnu\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\minnu\anaconda3\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets->qiskit-textbook==0.1.0) (305.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (3.1.2)
# Requirement already satisfied: prometheus-client in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\minnu\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (21.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\minnu\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\minnu\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\minnu\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (2023.7.22)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\minnu\anaconda3\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in c:\users\minnu\anaconda3\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (39.0.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\minnu\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\minnu\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.24.0->qiskit->qiskit-textbook==0.1.0) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\minnu\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (1.15.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\minnu\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\minnu\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.23.4)
# Requirement already satisfied: bleach in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (4.11.1)
# Requirement already satisfied: tinycss2 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.1.2)
# Requirement already satisfied: lxml in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (4.9.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\minnu\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.5.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\minnu\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\minnu\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\minnu\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit->qiskit-textbook==0.1.0) (2.21)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\minnu\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\minnu\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\minnu\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\minnu\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->qiskit-textbook==0.1.0) (1.2.0)
# Building wheels for collected packages: qiskit-textbook
#   Building wheel for qiskit-textbook (setup.py): started
#   Building wheel for qiskit-textbook (setup.py): finished with status 'done'
#   Created wheel for qiskit-textbook: filename=qiskit_textbook-0.1.0-py3-none-any.whl size=17644 sha256=4e23ba7a83bb94038cf8e5742dab98642c3663538219d06a69a29f3b05938bb5
#   Stored in directory: C:\Users\Minnu\AppData\Local\Temp\pip-ephem-wheel-cache-ssz77zqr\wheels\a4\af\1e\358474758f89b7223d73e3a3b05d32a15554fede054868448c
# Successfully built qiskit-textbook
# Installing collected packages: qiskit-textbook
# Successfully installed qiskit-textbook-0.1.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/qiskit-community/qiskit-textbook.git 'C:\Users\Minnu\AppData\Local\Temp\pip-req-build-03ik9flx'

# %%
conda install git
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Minnu\anaconda3
#
#   added / updated specs:
#     - git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.08.22 |       haa95532_0         123 KB
#     certifi-2023.7.22          |  py310haa95532_0         154 KB
#     git-2.40.1                 |       haa95532_1        69.2 MB
#     openssl-1.1.1w             |       h2bbff1b_0         5.5 MB
#     ------------------------------------------------------------
#                                            Total:        75.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   git                pkgs/main/win-64::git-2.40.1-haa95532_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-haa95532_0 --> 2023.08.22-haa95532_0
#   certifi                         2022.12.7-py310haa95532_0 --> 2023.7.22-py310haa95532_0
#   openssl                                 1.1.1t-h2bbff1b_0 --> 1.1.1w-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2023 | 123 KB    |            |   0%
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
#
#
# certifi-2023.7.22    | 154 KB    |            |   0%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   0%
#
# openssl-1.1.1w       | 5.5 MB    |            |   0%
# ca-certificates-2023 | 123 KB    | #2         |  13%
#
#
# certifi-2023.7.22    | 154 KB    | #          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   0%
#
# openssl-1.1.1w       | 5.5 MB    | 1          |   1%
# ca-certificates-2023 | 123 KB    | #####1     |  52%
# ca-certificates-2023 | 123 KB    | ########## | 100%
#
# openssl-1.1.1w       | 5.5 MB    | 3          |   3%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   0%
#
#
# certifi-2023.7.22    | 154 KB    | ####1      |  42%
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
# openssl-1.1.1w       | 5.5 MB    | 5          |   5%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   0%
#
# openssl-1.1.1w       | 5.5 MB    | 9          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   0%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   1%
#
# openssl-1.1.1w       | 5.5 MB    | #5         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   |            |   1%
#
# openssl-1.1.1w       | 5.5 MB    | ##2        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | 1          |   1%
#
# openssl-1.1.1w       | 5.5 MB    | ##6        |  26%
#
# openssl-1.1.1w       | 5.5 MB    | ###        |  31%
#
#
#
# git-2.40.1           | 69.2 MB   | 1          |   1%
#
#
#
# git-2.40.1           | 69.2 MB   | 1          |   2%
#
# openssl-1.1.1w       | 5.5 MB    | ###4       |  35%
#
# openssl-1.1.1w       | 5.5 MB    | ###8       |  39%
#
#
#
# git-2.40.1           | 69.2 MB   | 2          |   2%
#
# openssl-1.1.1w       | 5.5 MB    | ####3      |  43%
#
#
#
# git-2.40.1           | 69.2 MB   | 2          |   2%
#
#
#
# git-2.40.1           | 69.2 MB   | 2          |   3%
#
# openssl-1.1.1w       | 5.5 MB    | ####7      |  47%
#
#
#
# git-2.40.1           | 69.2 MB   | 2          |   3%
#
# openssl-1.1.1w       | 5.5 MB    | #####3     |  54%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   3%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   3%
#
# openssl-1.1.1w       | 5.5 MB    | #####7     |  57%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   3%
#
# openssl-1.1.1w       | 5.5 MB    | ######1    |  62%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   4%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   4%
#
# openssl-1.1.1w       | 5.5 MB    | ######5    |  65%
#
#
#
# git-2.40.1           | 69.2 MB   | 3          |   4%
#
# openssl-1.1.1w       | 5.5 MB    | ######7    |  68%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   4%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   4%
#
# openssl-1.1.1w       | 5.5 MB    | ######9    |  70%
#
# openssl-1.1.1w       | 5.5 MB    | #######1   |  72%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   4%
#
# openssl-1.1.1w       | 5.5 MB    | #######3   |  74%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   4%
#
# openssl-1.1.1w       | 5.5 MB    | #######5   |  75%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | #######6   |  77%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | #######8   |  78%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | #######9   |  80%
#
#
#
# git-2.40.1           | 69.2 MB   | 4          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########1  |  81%
#
# openssl-1.1.1w       | 5.5 MB    | ########2  |  82%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########3  |  84%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########5  |  85%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########6  |  87%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########7  |  88%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | ########9  |  89%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | #########  |  90%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   5%
#
# openssl-1.1.1w       | 5.5 MB    | #########1 |  92%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########2 |  93%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########4 |  94%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########5 |  95%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########6 |  96%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
#
#
# git-2.40.1           | 69.2 MB   | 5          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########7 |  98%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | #########8 |  99%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
# openssl-1.1.1w       | 5.5 MB    | ########## | 100%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   6%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 6          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   7%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 7          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   8%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   | 8          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |   9%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   | 9          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   | #          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   | #          |  10%
#
#
#
# git-2.40.1           | 69.2 MB   | #          |  11%
#
#
#
# git-2.40.1           | 69.2 MB   | #          |  11%
#
#
#
# git-2.40.1           | 69.2 MB   | #1         |  11%
#
#
#
# git-2.40.1           | 69.2 MB   | #1         |  11%
#
#
#
# git-2.40.1           | 69.2 MB   | #1         |  12%
#
#
#
# git-2.40.1           | 69.2 MB   | #1         |  12%
#
#
#
# git-2.40.1           | 69.2 MB   | #2         |  12%
#
#
#
# git-2.40.1           | 69.2 MB   | #2         |  12%
#
#
#
# git-2.40.1           | 69.2 MB   | #2         |  13%
#
#
#
# git-2.40.1           | 69.2 MB   | #2         |  13%
#
#
#
# git-2.40.1           | 69.2 MB   | #2         |  13%
#
#
#
# git-2.40.1           | 69.2 MB   | #3         |  13%
#
#
#
# git-2.40.1           | 69.2 MB   | #3         |  13%
#
#
#
# git-2.40.1           | 69.2 MB   | #3         |  14%
#
#
#
# git-2.40.1           | 69.2 MB   | #3         |  14%
#
#
#
# git-2.40.1           | 69.2 MB   | #4         |  14%
#
#
#
# git-2.40.1           | 69.2 MB   | #4         |  14%
#
#
#
# git-2.40.1           | 69.2 MB   | #4         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   | #4         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   | #4         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   | #5         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   | #5         |  15%
#
#
#
# git-2.40.1           | 69.2 MB   | #5         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #5         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #5         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  16%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #6         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  17%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #7         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  18%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #8         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  19%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | #9         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  20%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##         |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  21%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##1        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  22%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##2        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  23%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##3        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  24%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##4        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##5        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##5        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##5        |  25%
#
#
#
# git-2.40.1           | 69.2 MB   | ##5        |  26%
#
#
#
# git-2.40.1           | 69.2 MB   | ##5        |  26%
#
#
#
# git-2.40.1           | 69.2 MB   | ##6        |  26%
#
#
#
# git-2.40.1           | 69.2 MB   | ##6        |  26%
#
#
#
# git-2.40.1           | 69.2 MB   | ##6        |  26%
#
#
#
# git-2.40.1           | 69.2 MB   | ##6        |  27%
#
#
#
# git-2.40.1           | 69.2 MB   | ##6        |  27%
#
#
#
# git-2.40.1           | 69.2 MB   | ##7        |  27%
#
#
#
# git-2.40.1           | 69.2 MB   | ##7        |  27%
#
#
#
# git-2.40.1           | 69.2 MB   | ##7        |  28%
#
#
#
# git-2.40.1           | 69.2 MB   | ##7        |  28%
#
#
#
# git-2.40.1           | 69.2 MB   | ##7        |  28%
#
#
#
# git-2.40.1           | 69.2 MB   | ##8        |  28%
#
#
#
# git-2.40.1           | 69.2 MB   | ##8        |  28%
#
#
#
# git-2.40.1           | 69.2 MB   | ##8        |  29%
#
#
#
# git-2.40.1           | 69.2 MB   | ##8        |  29%
#
#
#
# git-2.40.1           | 69.2 MB   | ##9        |  29%
#
#
#
# git-2.40.1           | 69.2 MB   | ##9        |  29%
#
#
#
# git-2.40.1           | 69.2 MB   | ##9        |  29%
#
#
#
# git-2.40.1           | 69.2 MB   | ##9        |  30%
#
#
#
# git-2.40.1           | 69.2 MB   | ##9        |  30%
#
#
#
# git-2.40.1           | 69.2 MB   | ###        |  30%
#
#
#
# git-2.40.1           | 69.2 MB   | ###        |  30%
#
#
#
# git-2.40.1           | 69.2 MB   | ###        |  30%
#
#
#
# git-2.40.1           | 69.2 MB   | ###        |  31%
#
#
#
# git-2.40.1           | 69.2 MB   | ###        |  31%
#
#
#
# git-2.40.1           | 69.2 MB   | ###1       |  31%
#
#
#
# git-2.40.1           | 69.2 MB   | ###1       |  31%
#
#
#
# git-2.40.1           | 69.2 MB   | ###1       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###1       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###1       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  32%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###2       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  33%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  34%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  34%
#
#
#
# git-2.40.1           | 69.2 MB   | ###3       |  34%
#
#
#
# git-2.40.1           | 69.2 MB   | ###4       |  34%
#
#
#
# git-2.40.1           | 69.2 MB   | ###4       |  34%
#
#
#
# git-2.40.1           | 69.2 MB   | ###4       |  35%
#
#
#
# git-2.40.1           | 69.2 MB   | ###4       |  35%
#
#
#
# git-2.40.1           | 69.2 MB   | ###5       |  35%
#
#
#
# git-2.40.1           | 69.2 MB   | ###5       |  35%
#
#
#
# git-2.40.1           | 69.2 MB   | ###5       |  36%
#
#
#
# git-2.40.1           | 69.2 MB   | ###5       |  36%
#
#
#
# git-2.40.1           | 69.2 MB   | ###6       |  36%
#
#
#
# git-2.40.1           | 69.2 MB   | ###6       |  36%
#
#
#
# git-2.40.1           | 69.2 MB   | ###6       |  37%
#
#
#
# git-2.40.1           | 69.2 MB   | ###6       |  37%
#
#
#
# git-2.40.1           | 69.2 MB   | ###7       |  37%
#
#
#
# git-2.40.1           | 69.2 MB   | ###7       |  38%
#
#
#
# git-2.40.1           | 69.2 MB   | ###7       |  38%
#
#
#
# git-2.40.1           | 69.2 MB   | ###8       |  38%
#
#
#
# git-2.40.1           | 69.2 MB   | ###8       |  38%
#
#
#
# git-2.40.1           | 69.2 MB   | ###8       |  39%
#
#
#
# git-2.40.1           | 69.2 MB   | ###8       |  39%
#
#
#
# git-2.40.1           | 69.2 MB   | ###9       |  39%
#
#
#
# git-2.40.1           | 69.2 MB   | ###9       |  39%
#
#
#
# git-2.40.1           | 69.2 MB   | ###9       |  40%
#
#
#
# git-2.40.1           | 69.2 MB   | ####       |  40%
#
#
#
# git-2.40.1           | 69.2 MB   | ####       |  40%
#
#
#
# git-2.40.1           | 69.2 MB   | ####       |  41%
#
#
#
# git-2.40.1           | 69.2 MB   | ####       |  41%
#
#
#
# git-2.40.1           | 69.2 MB   | ####1      |  41%
#
#
#
# git-2.40.1           | 69.2 MB   | ####1      |  42%
#
#
#
# git-2.40.1           | 69.2 MB   | ####1      |  42%
#
#
#
# git-2.40.1           | 69.2 MB   | ####2      |  42%
#
#
#
# git-2.40.1           | 69.2 MB   | ####2      |  42%
#
#
#
# git-2.40.1           | 69.2 MB   | ####2      |  43%
#
#
#
# git-2.40.1           | 69.2 MB   | ####3      |  43%
#
#
#
# git-2.40.1           | 69.2 MB   | ####3      |  44%
#
#
#
# git-2.40.1           | 69.2 MB   | ####3      |  44%
#
#
#
# git-2.40.1           | 69.2 MB   | ####4      |  44%
#
#
#
# git-2.40.1           | 69.2 MB   | ####4      |  45%
#
#
#
# git-2.40.1           | 69.2 MB   | ####4      |  45%
#
#
#
# git-2.40.1           | 69.2 MB   | ####5      |  45%
#
#
#
# git-2.40.1           | 69.2 MB   | ####5      |  46%
#
#
#
# git-2.40.1           | 69.2 MB   | ####5      |  46%
#
#
#
# git-2.40.1           | 69.2 MB   | ####6      |  46%
#
#
#
# git-2.40.1           | 69.2 MB   | ####6      |  47%
#
#
#
# git-2.40.1           | 69.2 MB   | ####6      |  47%
#
#
#
# git-2.40.1           | 69.2 MB   | ####7      |  47%
#
#
#
# git-2.40.1           | 69.2 MB   | ####7      |  48%
#
#
#
# git-2.40.1           | 69.2 MB   | ####7      |  48%
#
#
#
# git-2.40.1           | 69.2 MB   | ####8      |  48%
#
#
#
# git-2.40.1           | 69.2 MB   | ####8      |  49%
#
#
#
# git-2.40.1           | 69.2 MB   | ####8      |  49%
#
#
#
# git-2.40.1           | 69.2 MB   | ####9      |  49%
#
#
#
# git-2.40.1           | 69.2 MB   | ####9      |  50%
#
#
#
# git-2.40.1           | 69.2 MB   | ####9      |  50%
#
#
#
# git-2.40.1           | 69.2 MB   | #####      |  50%
#
#
#
# git-2.40.1           | 69.2 MB   | #####      |  51%
#
#
#
# git-2.40.1           | 69.2 MB   | #####1     |  51%
#
#
#
# git-2.40.1           | 69.2 MB   | #####1     |  51%
#
#
#
# git-2.40.1           | 69.2 MB   | #####1     |  52%
#
#
#
# git-2.40.1           | 69.2 MB   | #####1     |  52%
#
#
#
# git-2.40.1           | 69.2 MB   | #####2     |  52%
#
#
#
# git-2.40.1           | 69.2 MB   | #####2     |  53%
#
#
#
# git-2.40.1           | 69.2 MB   | #####3     |  53%
#
#
#
# git-2.40.1           | 69.2 MB   | #####3     |  53%
#
#
#
# git-2.40.1           | 69.2 MB   | #####3     |  54%
#
#
#
# git-2.40.1           | 69.2 MB   | #####4     |  54%
#
#
#
# git-2.40.1           | 69.2 MB   | #####4     |  54%
#
#
#
# git-2.40.1           | 69.2 MB   | #####4     |  55%
#
#
#
# git-2.40.1           | 69.2 MB   | #####5     |  55%
#
#
#
# git-2.40.1           | 69.2 MB   | #####5     |  55%
#
#
#
# git-2.40.1           | 69.2 MB   | #####5     |  56%
#
#
#
# git-2.40.1           | 69.2 MB   | #####6     |  56%
#
#
#
# git-2.40.1           | 69.2 MB   | #####6     |  57%
#
#
#
# git-2.40.1           | 69.2 MB   | #####6     |  57%
#
#
#
# git-2.40.1           | 69.2 MB   | #####7     |  57%
#
#
#
# git-2.40.1           | 69.2 MB   | #####7     |  58%
#
#
#
# git-2.40.1           | 69.2 MB   | #####7     |  58%
#
#
#
# git-2.40.1           | 69.2 MB   | #####8     |  58%
#
#
#
# git-2.40.1           | 69.2 MB   | #####8     |  59%
#
#
#
# git-2.40.1           | 69.2 MB   | #####8     |  59%
#
#
#
# git-2.40.1           | 69.2 MB   | #####9     |  59%
#
#
#
# git-2.40.1           | 69.2 MB   | #####9     |  60%
#
#
#
# git-2.40.1           | 69.2 MB   | ######     |  60%
#
#
#
# git-2.40.1           | 69.2 MB   | ######     |  61%
#
#
#
# git-2.40.1           | 69.2 MB   | ######     |  61%
#
#
#
# git-2.40.1           | 69.2 MB   | ######1    |  61%
#
#
#
# git-2.40.1           | 69.2 MB   | ######1    |  62%
#
#
#
# git-2.40.1           | 69.2 MB   | ######2    |  62%
#
#
#
# git-2.40.1           | 69.2 MB   | ######2    |  62%
#
#
#
# git-2.40.1           | 69.2 MB   | ######2    |  63%
#
#
#
# git-2.40.1           | 69.2 MB   | ######3    |  63%
#
#
#
# git-2.40.1           | 69.2 MB   | ######3    |  64%
#
#
#
# git-2.40.1           | 69.2 MB   | ######3    |  64%
#
#
#
# git-2.40.1           | 69.2 MB   | ######4    |  64%
#
#
#
# git-2.40.1           | 69.2 MB   | ######4    |  65%
#
#
#
# git-2.40.1           | 69.2 MB   | ######4    |  65%
#
#
#
# git-2.40.1           | 69.2 MB   | ######5    |  65%
#
#
#
# git-2.40.1           | 69.2 MB   | ######5    |  66%
#
#
#
# git-2.40.1           | 69.2 MB   | ######6    |  66%
#
#
#
# git-2.40.1           | 69.2 MB   | ######6    |  66%
#
#
#
# git-2.40.1           | 69.2 MB   | ######6    |  67%
#
#
#
# git-2.40.1           | 69.2 MB   | ######7    |  67%
#
#
#
# git-2.40.1           | 69.2 MB   | ######7    |  68%
#
#
#
# git-2.40.1           | 69.2 MB   | ######8    |  68%
#
#
#
# git-2.40.1           | 69.2 MB   | ######8    |  69%
#
#
#
# git-2.40.1           | 69.2 MB   | ######9    |  69%
#
#
#
# git-2.40.1           | 69.2 MB   | ######9    |  70%
#
#
#
# git-2.40.1           | 69.2 MB   | #######    |  70%
#
#
#
# git-2.40.1           | 69.2 MB   | #######    |  71%
#
#
#
# git-2.40.1           | 69.2 MB   | #######1   |  71%
#
#
#
# git-2.40.1           | 69.2 MB   | #######1   |  72%
#
#
#
# git-2.40.1           | 69.2 MB   | #######1   |  72%
#
#
#
# git-2.40.1           | 69.2 MB   | #######2   |  72%
#
#
#
# git-2.40.1           | 69.2 MB   | #######2   |  73%
#
#
#
# git-2.40.1           | 69.2 MB   | #######3   |  73%
#
#
#
# git-2.40.1           | 69.2 MB   | #######3   |  74%
#
#
#
# git-2.40.1           | 69.2 MB   | #######4   |  74%
#
#
#
# git-2.40.1           | 69.2 MB   | #######5   |  75%
#
#
#
# git-2.40.1           | 69.2 MB   | #######5   |  76%
#
#
#
# git-2.40.1           | 69.2 MB   | #######6   |  76%
#
#
#
# git-2.40.1           | 69.2 MB   | #######6   |  76%
#
#
#
# git-2.40.1           | 69.2 MB   | #######6   |  77%
#
#
#
# git-2.40.1           | 69.2 MB   | #######7   |  77%
#
#
#
# git-2.40.1           | 69.2 MB   | #######7   |  78%
#
#
#
# git-2.40.1           | 69.2 MB   | #######8   |  78%
#
#
#
# git-2.40.1           | 69.2 MB   | #######8   |  79%
#
#
#
# git-2.40.1           | 69.2 MB   | #######9   |  79%
#
#
#
# git-2.40.1           | 69.2 MB   | #######9   |  80%
#
#
#
# git-2.40.1           | 69.2 MB   | ########   |  81%
#
#
#
# git-2.40.1           | 69.2 MB   | ########1  |  81%
#
#
#
# git-2.40.1           | 69.2 MB   | ########1  |  82%
#
#
#
# git-2.40.1           | 69.2 MB   | ########2  |  82%
#
#
#
# git-2.40.1           | 69.2 MB   | ########2  |  83%
#
#
#
# git-2.40.1           | 69.2 MB   | ########3  |  83%
#
#
#
# git-2.40.1           | 69.2 MB   | ########3  |  84%
#
#
#
# git-2.40.1           | 69.2 MB   | ########4  |  84%
#
#
#
# git-2.40.1           | 69.2 MB   | ########4  |  85%
#
#
#
# git-2.40.1           | 69.2 MB   | ########5  |  85%
#
#
#
# git-2.40.1           | 69.2 MB   | ########5  |  86%
#
#
#
# git-2.40.1           | 69.2 MB   | ########6  |  86%
#
#
#
# git-2.40.1           | 69.2 MB   | ########6  |  87%
#
#
#
# git-2.40.1           | 69.2 MB   | ########7  |  88%
#
#
#
# git-2.40.1           | 69.2 MB   | ########8  |  88%
#
#
#
# git-2.40.1           | 69.2 MB   | ########8  |  89%
#
#
#
# git-2.40.1           | 69.2 MB   | ########9  |  89%
#
#
#
# git-2.40.1           | 69.2 MB   | ########9  |  90%
#
#
#
# git-2.40.1           | 69.2 MB   | #########  |  90%
#
#
#
# git-2.40.1           | 69.2 MB   | #########  |  91%
#
#
#
# git-2.40.1           | 69.2 MB   | #########1 |  91%
#
#
#
# git-2.40.1           | 69.2 MB   | #########2 |  92%
#
#
#
# git-2.40.1           | 69.2 MB   | #########2 |  93%
#
#
#
# git-2.40.1           | 69.2 MB   | #########3 |  93%
#
#
#
# git-2.40.1           | 69.2 MB   | #########3 |  94%
#
#
#
# git-2.40.1           | 69.2 MB   | #########4 |  94%
#
#
#
# git-2.40.1           | 69.2 MB   | #########5 |  95%
#
#
#
# git-2.40.1           | 69.2 MB   | #########5 |  96%
#
#
#
# git-2.40.1           | 69.2 MB   | #########6 |  96%
#
#
#
# git-2.40.1           | 69.2 MB   | #########6 |  97%
#
#
#
# git-2.40.1           | 69.2 MB   | #########7 |  97%
#
#
#
# git-2.40.1           | 69.2 MB   | #########7 |  98%
#
#
#
# git-2.40.1           | 69.2 MB   | #########8 |  98%
#
#
#
# git-2.40.1           | 69.2 MB   | #########8 |  99%
#
#
#
# git-2.40.1           | 69.2 MB   | #########9 |  99%
#
#
#
# git-2.40.1           | 69.2 MB   | #########9 | 100%
#
#
#
# git-2.40.1           | 69.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0
